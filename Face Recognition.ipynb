# %%
import cv2

# Load the Haar Cascade for face detection
face_cap = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Check if the cascade is loaded correctly
if face_cap.empty():
    print("Error: Failed to load Haar Cascade XML file.")
    exit()

# Open the webcam
video_cap = cv2.VideoCapture(0)

# Check if the camera opened successfully
if not video_cap.isOpened():
    print("Error: Cannot open camera.")
    exit()

print("Camera started. Press 'a' to exit.")

while True:
    ret, video_data = video_cap.read()
    if not ret:
        print("Warning: Failed to grab frame.")
        break

    # Convert to grayscale
    col = cv2.cvtColor(video_data, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cap.detectMultiScale(
        col,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )

    # Draw rectangles around detected faces
    for (x, y, w, h) in faces:
        cv2.rectangle(video_data, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Show the video feed
    cv2.imshow("AI_cam by Arnav", video_data)

    # Press 'a' to quit
    if cv2.waitKey(10) == ord("a"):
        print("Exiting...")
        break

# Release the camera and close all windows
video_cap.release()
cv2.destroyAllWindows()
# Out:
# Camera started. Press 'a' to exit.
# Warning: Failed to grab frame.
